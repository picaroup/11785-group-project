# %%
import librosa
import os
import pandas as pd

def get_personality_scores(data_dir_path):
    df = pd.read_csv(data_dir_path + "/Score_011.csv")

    for i in range(1, 11):
        df_tmp = pd.read_csv(data_dir_path + f"/Score_0{i:02d}.csv")
        
        df["Extraversion"] = df["Extraversion"] + df_tmp["Extraversion"]
        df["Agreeableness"] = df["Agreeableness"] + df_tmp["Agreeableness"]
        df["Conscientiousness"] = df["Conscientiousness"] + df_tmp["Conscientiousness"]
        df["Neuroticism"] = df["Neuroticism"] + df_tmp["Neuroticism"]
        df["Openness"] = df["Openness"] + df_tmp["Openness"]

    df["Extraversion"] = df["Extraversion"] / 11
    df["Agreeableness"] = df["Agreeableness"] / 11
    df["Conscientiousness"] = df["Conscientiousness"] / 11
    df["Neuroticism"] = df["Neuroticism"] / 11
    df["Openness"] = df["Openness"] / 11
    
    return df

def get_metadata(data_dir_path):
    df = pd.read_csv(data_dir_path + "/Metadata.csv")
    return df

def get_features(data_dir_path):
    data = []
    
    for filename in os.listdir(data_dir_path):
        f = os.path.join(data_dir_path, filename)
        
        y, sr = librosa.load(f)
        output = []
        for config in configs:
            s = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=config[0], hop_length=config[1], win_length=config[2])
            print(s.shape)
            output.append(s)
        print("------")
        data.append([filename.split(".")[0], output])
    
    df = pd.DataFrame(data, columns=["Clip_ID", "features"])
    return df

# %%
configs = [
    [2048, 512, 2048],
    [2048, 512, 1024],
    [2048, 1024, 1024],
    [1024, 512, 1024],
    [1024, 256, 1024]
]

# %%
personality_dir="data/Personality_Scores"
metadata_dir="data/Metadata"
audio_dir="data/Audio_clips"

df_personality = get_personality_scores(personality_dir)
df_metadata = get_metadata(metadata_dir)
df_feature = get_features(audio_dir)

df = pd.merge(df_personality, df_metadata, left_on="Clip_ID", right_on="Clip_ID")
df = pd.merge(df, df_feature, left_on="Clip_ID", right_on="Clip_ID")

df.head()
# Out:
# (128, 431)
# (128, 431)
# (128, 216)
# (128, 431)
# (128, 862)
# ------
# (128, 431)
# (128, 431)
# (128, 216)
# (128, 431)
# (128, 862)
# ------
# (128, 278)
# (128, 278)
# (128, 139)
# (128, 278)
# (128, 556)
# ------
# (128, 431)
# (128, 431)
# (128, 216)
# (128, 431)
# (128, 862)
# ------
# (128, 314)
# (128, 314)
# (128, 157)
# (128, 314)
# (128, 628)
# ------
# (128, 431)
# (128, 431)
# (128, 216)
# (128, 431)
# (128, 862)
# ------
# (128, 431)
# (128, 431)
# (128, 216)
# (128, 431)
# (128, 862)
# ------
# (128, 431)
# (128, 431)
# (128, 216)
# (128, 431)
# (128, 862)
# ------
# (128, 431)
# (128, 431)
# (128, 216)
# (128, 431)
# (128, 862)
# ------
# (128, 431)
# (128, 431)
# (128, 216)
# (128, 431)
# (128, 862)
# ------
# (128, 431)
# (128, 431)
# (128, 216)
# (128, 431)
# (128, 862)
# ------
# (128, 431)
# (128, 431)
# (128, 216)
# (128, 431)
# (128, 862)
# ------
# (128, 431)
# (128, 431)
# (128, 216)
# (128, 431)
# (128, 862)
# ------
# (128, 431)
# (128, 431)
# (128, 216)
# (128, 431)
# (128, 862)
# ------
# (128, 431)
# (128, 431)
# (128, 216)
# (128, 431)
# (128, 862)
# ------
# (128, 431)
# (128, 431)
# (128, 216)
# (128, 431)
# (128, 862)
# ------
# (128, 431)
# (128, 431)
# (128, 216)
# (128, 431)
# (128, 862)
# ------
# (128, 431)
# (128, 431)
# (128, 216)
# (128, 431)
# (128, 862)
# ------
# (128, 431)
# (128, 431)
# (128, 216)
# (128, 431)
# (128, 862)
# ------
# (128, 402)
# (128, 402)
# (128, 201)
# (128, 402)
# (128, 803)
# ------
# (128, 431)
# (128, 431)
# (128, 216)
# (128, 431)
# (128, 862)
# ------
# (128, 431)
# (128, 431)
# (128, 216)
# (128, 431)
# (128, 862)
# ------
# (128, 431)
# (128, 431)
# (128, 216)
# (128, 431)
# (128, 862)
# ------
# (128, 431)
# (128, 431)
# (128, 216)
# (128, 431)
# (128, 862)
# ------
# (128, 343)
# (128, 343)
# (128, 172)
# (128, 343)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/ultraman-ace-m78/11785-project/test.ipynb Cell 3' in <module>
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ultraman-ace-m78/11785-project/test.ipynb#ch0000002vscode-remote?line=4'>5</a> df_personality = get_personality_scores(personality_dir)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ultraman-ace-m78/11785-project/test.ipynb#ch0000002vscode-remote?line=5'>6</a> df_metadata = get_metadata(metadata_dir)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ultraman-ace-m78/11785-project/test.ipynb#ch0000002vscode-remote?line=6'>7</a> df_feature = get_features(audio_dir)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ultraman-ace-m78/11785-project/test.ipynb#ch0000002vscode-remote?line=8'>9</a> df = pd.merge(df_personality, df_metadata, left_on="Clip_ID", right_on="Clip_ID")
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ultraman-ace-m78/11785-project/test.ipynb#ch0000002vscode-remote?line=9'>10</a> df = pd.merge(df, df_feature, left_on="Clip_ID", right_on="Clip_ID")
#
# /home/ultraman-ace-m78/11785-project/test.ipynb Cell 1' in get_features(data_dir_path)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ultraman-ace-m78/11785-project/test.ipynb#ch0000000vscode-remote?line=35'>36</a> output = []
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ultraman-ace-m78/11785-project/test.ipynb#ch0000000vscode-remote?line=36'>37</a> for config in configs:
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ultraman-ace-m78/11785-project/test.ipynb#ch0000000vscode-remote?line=37'>38</a>     s = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=config[0], hop_length=config[1], win_length=config[2])
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ultraman-ace-m78/11785-project/test.ipynb#ch0000000vscode-remote?line=38'>39</a>     print(s.shape)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ultraman-ace-m78/11785-project/test.ipynb#ch0000000vscode-remote?line=39'>40</a>     output.append(s)
#
# File ~/venv/lib/python3.8/site-packages/librosa/util/decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      <a href='file:///home/ultraman-ace-m78/venv/lib/python3.8/site-packages/librosa/util/decorators.py?line=85'>86</a> extra_args = len(args) - len(all_args)
#      <a href='file:///home/ultraman-ace-m78/venv/lib/python3.8/site-packages/librosa/util/decorators.py?line=86'>87</a> if extra_args <= 0:
# ---> <a href='file:///home/ultraman-ace-m78/venv/lib/python3.8/site-packages/librosa/util/decorators.py?line=87'>88</a>     return f(*args, **kwargs)
#      <a href='file:///home/ultraman-ace-m78/venv/lib/python3.8/site-packages/librosa/util/decorators.py?line=89'>90</a> # extra_args > 0
#      <a href='file:///home/ultraman-ace-m78/venv/lib/python3.8/site-packages/librosa/util/decorators.py?line=90'>91</a> args_msg = [
#      <a href='file:///home/ultraman-ace-m78/venv/lib/python3.8/site-packages/librosa/util/decorators.py?line=91'>92</a>     "{}={}".format(name, arg)
#      <a href='file:///home/ultraman-ace-m78/venv/lib/python3.8/site-packages/librosa/util/decorators.py?line=92'>93</a>     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      <a href='file:///home/ultraman-ace-m78/venv/lib/python3.8/site-packages/librosa/util/decorators.py?line=93'>94</a> ]
#
# File ~/venv/lib/python3.8/site-packages/librosa/feature/spectral.py:2058, in melspectrogram(y, sr, S, n_fft, hop_length, win_length, window, center, pad_mode, power, **kwargs)
#    <a href='file:///home/ultraman-ace-m78/venv/lib/python3.8/site-packages/librosa/feature/spectral.py?line=2054'>2055</a> # Build a Mel filter
#    <a href='file:///home/ultraman-ace-m78/venv/lib/python3.8/site-packages/librosa/feature/spectral.py?line=2055'>2056</a> mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# -> <a href='file:///home/ultraman-ace-m78/venv/lib/python3.8/site-packages/librosa/feature/spectral.py?line=2057'>2058</a> return np.einsum("...ft,mf->...mt", S, mel_basis, optimize=True)
#
# File <__array_function__ internals>:5, in einsum(*args, **kwargs)
#
# File ~/venv/lib/python3.8/site-packages/numpy/core/einsumfunc.py:1407, in einsum(out, optimize, *operands, **kwargs)
#    <a href='file:///home/ultraman-ace-m78/venv/lib/python3.8/site-packages/numpy/core/einsumfunc.py?line=1403'>1404</a>     right_pos.append(input_right.find(s))
#    <a href='file:///home/ultraman-ace-m78/venv/lib/python3.8/site-packages/numpy/core/einsumfunc.py?line=1405'>1406</a> # Contract!
# -> <a href='file:///home/ultraman-ace-m78/venv/lib/python3.8/site-packages/numpy/core/einsumfunc.py?line=1406'>1407</a> new_view = tensordot(*tmp_operands, axes=(tuple(left_pos), tuple(right_pos)))
#    <a href='file:///home/ultraman-ace-m78/venv/lib/python3.8/site-packages/numpy/core/einsumfunc.py?line=1408'>1409</a> # Build a new view if needed
#    <a href='file:///home/ultraman-ace-m78/venv/lib/python3.8/site-packages/numpy/core/einsumfunc.py?line=1409'>1410</a> if (tensor_result != results_index) or handle_out:
#
# File <__array_function__ internals>:5, in tensordot(*args, **kwargs)
#
# File ~/venv/lib/python3.8/site-packages/numpy/core/numeric.py:1132, in tensordot(a, b, axes)
#    <a href='file:///home/ultraman-ace-m78/venv/lib/python3.8/site-packages/numpy/core/numeric.py?line=1129'>1130</a> at = a.transpose(newaxes_a).reshape(newshape_a)
#    <a href='file:///home/ultraman-ace-m78/venv/lib/python3.8/site-packages/numpy/core/numeric.py?line=1130'>1131</a> bt = b.transpose(newaxes_b).reshape(newshape_b)
# -> <a href='file:///home/ultraman-ace-m78/venv/lib/python3.8/site-packages/numpy/core/numeric.py?line=1131'>1132</a> res = dot(at, bt)
#    <a href='file:///home/ultraman-ace-m78/venv/lib/python3.8/site-packages/numpy/core/numeric.py?line=1132'>1133</a> return res.reshape(olda + oldb)
#
# File <__array_function__ internals>:5, in dot(*args, **kwargs)
#
# KeyboardInterrupt:
